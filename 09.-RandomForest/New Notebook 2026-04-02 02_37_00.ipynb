# %%
# %pip install -U optuna optuna-integration mlflow

# %%
from databricks.sdk.service.serving import EndpointTag

# %%
dbutils.library.restartPython()

# %%
import optuna

# %%
# %sql
--alter catalog dev
---enable predictive optimization;
alter schema dev.feature_store
enable predictive optimization;
